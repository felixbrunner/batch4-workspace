# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, confusion_matrix

import nltk
import spacy
from googletrans import Translator

# %%
from googletrans import Translator
translator = Translator()

def translate_column(df, column='source_title'):
    translated = []
    for i, text, lang in zip(df.index, df[column], df['lang']):
        if lang != 'en' and text == text:
            if lang != lang:
                lang = None
            try:
                translated += [translator.translate(text, src=lang, dest='en').text]
            except:
                translated += ['']
                print('ERROR AT {}'.format(i), text, lang)
        else:
            translated += [text]
        if i % 250 == 0:
            print('translated {} lines'.format(i+1))
    return translated

# %%
# translate train
#df_trans = pd.DataFrame()
df['source_title_en'] = translate_column(df)
df.to_csv('./train_data.csv')
# Out:
# translated 1 lines
# ERROR AT 20 VoxCheck - ТЕРМІНОВО, НАМ ВСІМ БРЕШУТЬ, ВСЯ ПРАВДА ПРО... | Facebook nan
# ERROR AT 30  Página no encontrada - El Surtidor nan
# ERROR AT 33 Misbar - مسبار nan
# ERROR AT 49 ပရုတ်ဆီကို ရေနွေးနဲ့ဖျော်ပြီး ထွက်လာတဲ့အငွေ့ကို ရှုခြင်းက COVID-19 ကို ကုသနိုင်တယ်ဆိုတဲ့ သတင်းမှား - Factcrescendo Myanmar nan
# ERROR AT 76 VoxCheck - "Терміново! Сенсаційна новина потрясла... | Facebook nan
# ERROR AT 109 Facebook nan
# ERROR AT 122
# 	[팩트체크] ① 마스크만 쓴 확진자…이송 지침 위반? | JTBC 뉴스
#  nan
# ERROR AT 137 Misbar - مسبار nan
# ERROR AT 164 VoxCheck - Епідемії кожні 100 років! Співпадіння? — не... | Facebook nan
# ERROR AT 197 ආලෝකමත් වූ නෙලුම් කුළුන අප්‍රේල් 11 කුරුණෑගලට දිස්වු ඡායාරූපක් නොවේ! - Factcrescendo Sri Lanka nan
# ERROR AT 220 Misbar - مسبار nan
# ERROR AT 234
# 	[팩트체크] 일본은 40장씩 마스크 무료 배포? 직접 확인해보니 | JTBC 뉴스
#  nan
# translated 251 lines
# ERROR AT 271 Misbar - مسبار nan
# ERROR AT 278 အသက် ၁၀ စက္ကန့်အောင့်ထားနိုင်ရုံနဲ့ ကိုရိုနာဗိုင်းရပ်စ်ရှိမရှိမသိရှိနိုင်ပါ - Factcrescendo Myanmar nan
# ERROR AT 346 පැරණි ඡායාරුපයක් යොදා ගනිමින් යුධ හමුදා දෛනික සේවා සපයන්නන් හට දැඩි දුස්කරතා රැසක් යනුවෙන් කල ප්‍රකාශයක්! - Factcrescendo Sri Lanka nan
# ERROR AT 383 කොරෝනා රෝගීන්ට සත්කාර කරන ශ්‍රී ලාංකික ගර්භනී වෛද්‍යවරිකගේ ඡායාරුපයක්ද? - Factcrescendo Sri Lanka nan
# ERROR AT 388 Misbar - مسبار nan
# translated 501 lines
# ERROR AT 512 Spondeo Media - Fact-Fact | Aunque este pudiera parecer un... | Facebook nan
# ERROR AT 547 John Dough Jr. - The picture says it all👀 | Facebook nan
# ERROR AT 558 Misbar - مسبار nan
# ERROR AT 576
# 	[팩트체크] "중국 당국이 예방책으로 마늘 꼽았다?" 허위정보 검증 | JTBC 뉴스
#  nan
# ERROR AT 594 YouTube nan
# ERROR AT 597 Misbar - مسبار nan
# ERROR AT 616
# 	[팩트체크] 예배 제한 행정명령, 위헌적 종교탄압? | JTBC 뉴스
#  nan
# ERROR AT 691 မြန်မာလူထုဟာ ကိုရိုနာဗိုင်းရပ်စ်ကို ခံနိုင်ရည်ရှိတဲ့ စားသောက်မှု ပုံစံရှိသတဲ့လား - Factcrescendo Myanmar nan
# ERROR AT 700
# 	[팩트체크] 신종 코로나 때문에 음주단속 안한다? | JTBC 뉴스
#  nan
# ERROR AT 701 Misbar - مسبار nan
# ERROR AT 730 Controinformazione - I telegiornali raccontano della nuova ondata di Covid in Brasile... Guardate gente e condividiamo. | Facebook nan
# ERROR AT 749 Misbar - مسبار nan
# translated 751 lines
# ERROR AT 753 YouTube nan
# ERROR AT 854 Misbar - مسبار nan
# ERROR AT 855 Ecuador Chequea - #Pilas 🧐 @ecuavisa no difundió que... | Facebook nan
# ERROR AT 860 ကိုရိုနာဗိုင်းရပ်စ်ဟာ ဝူဟန်ဓာတ်ခွဲခန်းကလုပ်တာလို့ နိုဗယ်ဆုရ ဂျပန်ဇီဝကမ္မ ဗေဒပါမောက္ခ Tasuku Honjoကပြောတယ်ဆိုတဲ့ သတင်းတု - Factcrescendo Myanmar nan
# ERROR AT 898 Misbar - مسبار nan
# ERROR AT 906 කොරොනා සහන ලබාදීමට අතුරු සම්මත අයවැයක් පාර්ලිමේන්තුවට ඉදිරිපත් වුයේ නැත! - Factcrescendo Sri Lanka nan
# ERROR AT 916 Ecuador Chequea - #NoComasCuento: @Salud_Ec no confirmó un... | Facebook nan
# ERROR AT 931 ชัวร์ก่อนแชร์ - #PanicToday
# #ตระหนกรายวัน
#
# 😷... | Facebook nan
# translated 1001 lines
# ERROR AT 1116 YouTube nan
# ERROR AT 1124 ชัวร์ก่อนแชร์ - มาตรการเยียวยา 5000 บาท
# กรอกเสร็จ... | Facebook nan
# ERROR AT 1125 Misbar - مسبار nan
# ERROR AT 1137
# 	[팩트체크] 신종 코로나, 황사 바람 타고 중국서 넘어온다? | JTBC 뉴스
#  nan
# ERROR AT 1148 ကိုဗစ်ကာလ စီးပွားရေးဂယက်နဲ့ ကိုရီးယားလုပ်ငန်းတွေ ရွေ့ပြောင်းမယ်ဆိုတဲ့ကိစ္စ nan
# ERROR AT 1194 Misbar - مسبار nan
# ERROR AT 1203
# 	[팩트체크] "비상약 준비" '서울의대 졸업생 단톡방' 글 진짜일까? | JTBC 뉴스
#  nan
# ERROR AT 1211 YouTube nan
# ERROR AT 1229 කොරෝනා රහස් බෙහෙතක් පිලිබඳ වෛද්‍ය සීතා අරඹේපොළ ප්‍රකාශ කලේ නැත! - Factcrescendo Sri Lanka nan
# ERROR AT 1231 Misbar - مسبار nan
# translated 1251 lines
# ERROR AT 1270 တမာရွက်စားလို့ မလေးရှားမှာ covid-19 ပျောက်တာအများကြီးရှိပြီဆိုတဲ့ သတင်းမှား - Factcrescendo Myanm
# ตรวจสอบข้อเท็จจริงโดย... | Facebook nan
# ERROR AT 5275 Misbar - مسبار nan
# ERROR AT 5334 VoxCheck - ТЕРМІНОВО, НАМ ВСІМ БРЕШУТЬ, ВСЯ ПРАВДА ПРО... | Facebook nan
# ERROR AT 5361 YouTube nan
# ERROR AT 5392 Sergio Jorge | Facebook nan
# ERROR AT 5406 VoxCheck - ТЕРМІНОВО, НАМ ВСІМ БРЕШУТЬ, ВСЯ ПРАВДА ПРО... | Facebook nan
# ERROR AT 5417 Misbar - مسبار nan
# ERROR AT 5437
# 	[팩트체크] '가짜 음성' 의혹으로 '진단키트' 흔드는 주장, 진실은? | JTBC 뉴스
#  nan
# ERROR AT 5462 VoxCheck - ТЕРМІНОВО, НАМ ВСІМ БРЕШУТЬ, ВСЯ ПРАВДА ПРО... | Facebook nan
# ERROR AT 5473 Misbar - مسبار nan
# translated 5501 lines
# ERROR AT 5503 Misbar - مسبار nan
# ERROR AT 5510 Misbar - مسبار nan
# ERROR AT 5512 VoxCheck - ТЕРМІНОВО, НАМ ВСІМ БРЕШУТЬ, ВСЯ ПРАВДА ПРО... | Facebook nan
# ERROR AT 5524 Misbar - مسبار nan

# %%
# translate test
#df_trans = pd.DataFrame()
df_test['source_title_en'] = translate_column(df_test)
df_test.to_csv('./test_data.csv', index=False)
# Out:
# translated 1 lines
# ERROR AT 48
# 	[팩트체크] "중국 당국이 예방책으로 마늘 꼽았다?" 허위정보 검증 | JTBC 뉴스
#  None
# ERROR AT 52 Misbar - مسبار None
# ERROR AT 58 ပိုဗီဒုန်း အိုင်အိုဒင်း(Povidone-Iodine)ဟာ COVID-19 ကို ကုသနိုင်၊ ကာကွယ်နိုင်တယ် ဆိုတဲ့ အထောက်အထားခိုင်ခိုင်မာမာမရှိသေးပါ - Factcrescendo Myanmar None
# ERROR AT 66 නාවුක හමුදා සෙබළුන්ට වෛද්‍ය ඒලියන්ත වයිට්ගේ ප්‍රතිකාරයක් ලබාදෙන්නේ නැත! - Factcrescendo Sri Lanka None
# ERROR AT 76 ඉන්දීය සුපිරි නළු අමීර් කාන් පාන්පිටි මලු වල සඟවා මුදල් බෙදා ඇති බවට සමාජ මාධ්‍ය තුල සංසරනය ව්‍යාජ පුවතක් - Factcrescendo Sri Lanka None
# ERROR AT 98 ප්‍රභූ PCR පරීක්ෂණ1000 කට අධික ප්‍රමාණයක් දිනයකදී සිදුවූ බවට කළ සාවද්‍ය ප්‍රකාශයක්! - Factcrescendo Sri Lanka None
# ERROR AT 118 အများပြည်သူ ထိတ်လန့်အောင် လှုံ့ဆော်တဲ့ သတင်းအတု None
# ERROR AT 136 COVID-19 လူနာနဲ့ထိတွေ့ခဲ့တဲ့ သမ္မတနှင့် အတိုင်ပင်ခံပုဂ္ဂိုလ် ၁၄ ရက် self-quarantine လုပ်နေရဆိုတဲ့ သတင်းမှား - Factcrescendo Myanm
# ERROR AT 781 Fact Check :ජපානයේ පැරණි ඡායාරූපයක්, ලොව විවිධ නගර වසා දැමීමත් සමගම නිදහසේ සැරිසරන මුවන් ලෙස පෙන්වා දීමකි! - Factcrescendo Sri Lanka None
# ERROR AT 813 රජයේ සේවයේ මැයි මස වැටුප පරිත්‍යාග කිරීම සදහා භාවිතාකල යුතු ආකෘති පත්‍රයක් ? - Factcrescendo Sri Lanka None
# ERROR AT 904 ඡායාරූපයේ දැක්වෙන්නේ ශ්‍රී ලංකාවේ සෞඛ්‍ය කාර්ය මණ්ඩලයක් නොවේ! - Factcrescendo Sri Lanka None
# ERROR AT 930 අජිත් නිවාර්ඩ් කබ්රාල් කබ්රාල් මහතා සම්බන්ධයෙන් පළවූ සාවද්‍ය පුවතක්! - Factcrescendo Sri Lanka None
# ERROR AT 935 YouTube None
# ERROR AT 954 တရုတ်ကထုတ်တဲ့အခု ကိုကာကိုလာအပြာဗူး( Pepsi)ထဲမှာ ကိုဗစ်တွေ တွေ့ရတယ် ဆိုတဲ့သတင်းမှား - Factcrescendo Myanmar None
# ERROR AT 956  Es FALSO que ONU ofrece ayuda alimentaria por el Coronavirus - El Surtidor None
# ERROR AT 965 Misbar - مسبار None
# translated 1001 lines
# ERROR AT 1081 ရန်ကုန်လေထုထဲ ကိုရိုနာဗိုင်းရပ်စ်မရှိပါ None
# ERROR AT 1085 ဒေးဗစ်လားကို မောင်းထုတ်ရေးတွေ့ဆုံပွဲဆိုင်းဘုတ်တဲ့လား.. အမှန်က ဒီလိုပါ - Factcrescendo Myanmar None
# ERROR AT 1100 YouTube None
# ERROR AT 1109 Misbar - مسبار None
# ERROR AT 1131 ชัวร์ก่อนแชร์ - #PanicToday
# #ตระหนกรายวัน
#
# 😷... | Facebook None
# ERROR AT 1135
# MediaWise on Instagram: “This post seems to be a tip from a Kansas hospital telling people that drinking alcohol beverages can help prevent COVID-19.🤔The formatting…”
#  None
# ERROR AT 1176 Misbar - مسبار None
# ERROR AT 1189 Misbar - مسبار None
# ERROR AT 1192 Ecuador Chequea - #FALSETA: Campaña en contra del coronavirus en Ecuador | Facebook None
# translated 1251 lines
# ERROR AT 1253 လျှက်ဆားနဲ့ ထုံးပွတ်ရှုရင် ကိုရိုနာဗိုင်းရပ်စ်သေစေတယ်ဆိုတဲ့ သတင်းမှား - Factcrescendo Myanmar None
# ERROR AT 1292 ලක්‍ෂ 3000ක වාහන ගන්න කැබිනට් ඇනුමැතියක් ලැබී නොමැත! - Factcrescendo Sri Lanka None
# ERROR AT 1307 YouTube None
# ERROR AT 1316 Misbar - مسبار None
# ERROR AT 1327 භුමිදානය නොවී ආදාහනය වීමට තරම් මුස්ලිම් ජාතිකයින් කළ වැරැද්ද කුමක්ද? - බිමල් රත්නායක - Factcrescendo Sri Lanka None
# ERROR AT 1334
# 	[팩트체크] "중국 당국이 예방책으로 마늘 꼽았다?" 허위정보 검증 | JTBC 뉴스
#  None
# ERROR AT 1348 ඇමරිකාව විසින් නිපදවූ කොරෝනා එන්නතක් නොවේ! දකුණු කොරියාවේ පරීක්ෂණ කට්ටලයකි. - Factcrescendo Sri Lanka None
# ERROR AT 1357 YouTube None
# ERROR AT 1358 ဆေးခြောက်က COVID-19 ကို ကာကွယ်ကုသနိုင်တယ်ဆိုတဲ့ ခိုင်မာတဲ့အထောက် အထား မရှိသေးပါ - Factcrescendo Myanmar None
# ERROR AT 1359 အသက်ရှုလေ့ကျင်ခန်းက ကိုရိုနာဗိုင်းရပ်စ်ကို ကာကွယ်နိုင်တယ်ဆိုတဲ့ သတင်းမှား - Factcrescendo Myanmar None
# ERROR AT 1394 ชัวร์ก่อนแชร์ - #PanicToday
# #ตระหนกรายวัน
#
# 😷... | Facebook None
# ERROR AT 1456 IDH රෝහලේ අත්‍යවශ්‍ය භාණ්ඩ හිඟයක් නැත - Factcrescendo Sri Lanka None
# ERROR AT 1476
# 	[팩트체크] ② 격리 중 우한 교민, 공용세탁실 쓴다? | JTBC 뉴스
#  None
# translated 1501 lines
# ERROR AT 1586 ၁၅ မိနစ်တိုင်းရေသောက်ခြင်းအားဖြင့် ကိုရိုနာဗိုင်းရပ်စ်ကို ကာကွယ်နိုင်တယ်ဆိုတဲ့ သတင်းမှား - Factcrescendo Myanmar None
# ERROR AT 1635
# 	[팩트체크] "10초 숨참기"가 코로나19 자가 진단법? | JTBC 뉴스
#  None
# ERROR AT 1647 Misbar - مسبار None
# ERROR AT 1652 Misbar - مسبار None
# ERROR AT 1665  Página no encontrada - El Surtidor None
# ERROR AT 1676 ကိုဗစ်ကာလ စီးပွားရေးဂယက်နဲ့ ကိုရီးယားလုပ်ငန်းတွေ ရွေ့ပြောင်းမယ်ဆိုတဲ့ကိစ္စ None
# translated 1751 lines
# ERROR AT 1762 Misbar - مسبار None
# ERROR AT 1775 Misbar - مسبار None
# ERROR AT 1780 Misbar - مسبار None
# ERROR AT 1787 ကိုရိုနာဗိုင်းရပ်စစ်ကူးစက်ရောဂါထိန်းချုပ်ရေး အလှူရှင်တွေကို ပုံဖျက်ထားတဲ့ သတင်းမှား - Factcrescendo Myanmar None
# ERROR AT 1811 COVID-19 ရောဂါနဲ့ဗိုက်တာမင်ဒီအကြောင်းလေ့လာမှုတွေရှိပေမဲ့ ကုသနိုင် ကာကွယ်နိုင်တဲ့အထောက်အထားမရှိပါ - Factcrescendo Myanmar None
# ERROR AT 1843 ရင်ထဲထိစေတဲ့ သားမိပုံက ကိုရိုနာဗိုင်းရပ်စ်ကူးစက်ခံရတာလား - Factcrescendo Myanmar None
# ERROR AT 1847
# 	[팩트체크] "중국 당국이 예방책으로 마늘 꼽았다?" 허위정보 검증 | JTBC 뉴스
#  None
# ERROR AT 1855 Misbar - مسبار None
# ERROR AT 1864 ကိုရိုနာကပ်ရောဂါနဲ့ပတ်သက်ပြီး မိုင်းဖုန်းဆရာတော်ကြီးမိန့်ကြားတယ်ဆိုတဲ့ သတင်းတု - Factcrescendo Myanmar None
# ERROR AT 1868 VoxCheck - Новий (черговий) фейк! Цього разу про відмову... | Facebook None
# ERROR AT 1883 ඇමෙරිකාවේ දුම්රිය මාර්ගයක පැරණි ඡායාරුපයක් යොදා ගනිමින් සිදුකරන ලද සාවද්‍ය ප්‍රකාශයක්! - Factcrescendo Sri Lanka None
# ERROR AT 1901
# 	[팩트체크] '감염병 예방' 종교모임 일시 금지, 가능할까? | JTBC 뉴스
#  None
# ERROR AT 1916 ඇඳිරි නීති සමයේ කුළු බඩු බෙදා දීමේදී පොහොට්ටුවේ ලාංඡනය සහිත ඇසුරුමක් යොදාගත්තේද? - Factcrescendo Sri Lanka None
# ERROR AT 1918  Página no encontrada - El Surtidor None
# ERROR AT 1992 Misbar - مسبار None
# ERROR AT 1999 YouTube None
# translated 2001 lines
# ERROR AT 2060 ရောဂါကာကွယ်ဆေးကို ရှာတွေ့ပြီလို့ ကျန်းမာရေးဝန်ကြီး သတင်းကောင်းပေးဆိုတဲ့ သတင်းမှား - Factcrescendo Myanmar None
# ERROR AT 2070 Misbar - مسبار None

# %%
(df['title'].str.count('[!@#$%^&*()_+\-=\[\]{}\\|<>\/?]')/df['title'].str.len())
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
#           ...
# 5526    0.000000
# 5527    0.000000
# 5528    0.000000
# 5529    0.030769
# 5530    0.011765
# Name: title, Length: 5531, dtype: float64

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('data/covid19_data.csv')
df_test = pd.read_csv('data/covid19_unlabelled_test.csv')
sample_submission = pd.read_csv('data/sample_submission.csv')

# %%
df.head(3)
# Out:
#                                verifiedby                       country  \
# 0   Delfi Melo Detektorius (Lie Detector)                     Lithuania
# 1                             AfricaCheck   United States, South Africa
# 2                                     AFP                     Hong Kong
#
#    class                                              title published_date  \
# 0  FALSE   Claims that coronavirus is fake and Belarus i...    2020/05/11
# 1  False   Muammar Gaddafi predicted the current coronav...    2020/03/21
# 2  False   Video shows quarantined people in a building ...    2020/02/17
#
#          country1       country2 country3 country4  \
# 0       Lithuania            NaN      NaN      NaN
# 1   United States   South Africa      NaN      NaN
# 2       Hong Kong            NaN      NaN      NaN
#
#                                       article_source ref_source  \
# 0  https://www.delfi.lt/news/melo-detektorius/mel...    poynter
# 1  https://africacheck.org/fbcheck/no-gaddafi-did...    poynter
# 2                   http://u.afp.com/QuarantineChina    poynter
#
#                                         source_title  \
# 0  Baltarusija atšventė nesisaugodama nuo koronav...
# 1  No, Gaddafi didn’t predict coronavirus, but di...
# 2  This video shows tower blocks in Shanghai, not...
#
#                                         content_text category lang
# 0  Gegužės 9-ąją Baltarusijos sostinėje Minske su...      NaN   lt
# 1  As the world struggles to bring the new corona...      NaN   en
# 2  It has been viewed more than 200,000 times., T...      NaN   en

# %%
df.describe()
# Out:
#        verifiedby country  class  \
# count        5531    5306   5529
# unique         96     344     60
# top           AFP   India  False
# freq          515    1054   2110
#
#                                                     title published_date  \
# count                                                5531           5531
# unique                                               5404            246
# top     Does Trump Own Stock in a Company CDC Uses for...    2020/03/17
# freq                                                    4            102
#
#        country1       country2        country3 country4  \
# count      5306            451              93       29
# unique      108             85              42       25
# top       India   North Africa   United States    Spain
# freq       1062            106               8        3
#
#                                            article_source ref_source  \
# count                                                5524       5531
# unique                                               5472          2
# top     http://www.ecuadorchequea.com/las-mentiras-sob...    poynter
# freq                                                   17       5306
#
#           source_title                                       content_text  \
# count             5189                                               4938
# unique            4838                                               4752
# top     Misbar - مسبار  Las mentiras sobre este tema abarcan desde la ...
# freq                79                                                 43
#
#                       category  lang
# count                      225  5281
# unique                      14    39
# top     US Government Response    en
# freq                        36  2069

# %%
df['class'].value_counts(normalize=True)
# Out:
# False                                 0.381624
# FALSE                                 0.376017
# Misleading                            0.083740
# MISLEADING                            0.031290
# Mostly false                          0.018267
# Partly false                          0.017906
# misleading                            0.014469
# No evidence                           0.010309
# Mostly False                          0.007777
# Mixture                               0.007415
# True                                  0.004522
# No Evidence                           0.004341
# Explanatory                           0.004341
# News                                  0.004160
# PARTLY FALSE                          0.003979
# Unproven                              0.002170
# MOSTLY FALSE                          0.001990
# Miscaptioned                          0.001809
# Partly False                          0.001809
# mostly false                          0.001628
# partly false                          0.001628
# Mostly True                           0.001447
# MOSTLY TRUE                           0.001266
# Misattributed                         0.001266
# (Org. doesn't apply rating)           0.001266
# HALF TRUE                             0.001085
# Labeled Satire                        0.000904
# Partially false                       0.000904
# Correct Attribution                   0.000904
# Fake                                  0.000723
# false                                 0.000543
# Two Pinocchios                        0.000543
# no evidence                           0.000543
# Scam                                  0.000543
# Half True                             0.000543
# NO EVIDENCE                           0.000543
# Not true                              0.000362
# Partly FALSE                          0.000362
# Suspicions                            0.000362
# half true                             0.000362
# PARTLY TRUE                           0.000362
# Misleading/False                      0.000362
# Correct                               0.000362
# mislEADING                            0.000362
# Unverified                            0.000181
# HALF TRUTH                            0.000181
# Mostly true                           0.000181
# MiSLEADING                            0.000181
# IN DISPUTE                            0.000181
# Mixed                                 0.000181
# Unlikely                              0.000181
# Partially true                        0.000181
# True but                              0.000181
# Fake news                             0.000181
# false and misleading                  0.000181
# Partly true                           0.000181
# Collections                           0.000181
# PANTS ON FIRE                         0.000181
# Misinformation / Conspiracy theory    0.000181
# Partially correct                     0.000181
# Name: class, dtype: float64

# %% [markdown]
# ## Preprocess
# ### Labels

# %%
def true_or_false(x):
    if x.lower() in ["correct", "true", "explanatory", "correct attribution", "news"]:
        x = "true"
    else:
        x = "false"
    return x

df['label'] = df["class"].apply(str).apply(true_or_false)

# %%
def build_labels(df, true_list=['True']):
    y = df['class'].copy()
    y.loc[[i in true_list for i in df['class']]] = 'true'
    return y

# %%
df['label'].value_counts(normalize=True)
# Out:
# false    0.985717
# true     0.014283
# Name: label, dtype: float64

# %% [markdown]
# ## Features

# %% [markdown]
# ## Baseline

# %%
# Split in train and validation
df_train, df_val = train_test_split(df, test_size=0.2, random_state=42, stratify=df['label'])

# Build the pipeline
clf = Pipeline([('tfidf', TfidfVectorizer()),
                ('classifier', RandomForestClassifier(random_state = 42))])

# Train the classifier
clf.fit(map(str, df_train['title'].values), df_train['label'].values)

# Predict train data
predicted_train = clf.predict(map(str, df_train['title'].values))
print('Train score: ', np.mean(predicted_train == df_train['label']))

# Predict validation data
predicted_val = clf.predict(map(str, df_val['title'].values))
print('Validation score: ', np.mean(predicted_val == df_val['label']))

# Predict test data
predicted_test = clf.predict(map(str, df_test['title'].values))
# Out:
# Train score:  1.0
# Validation score:  0.987353206865402

# %%
def build_submission(predictions):
    submission = pd.DataFrame()
    submission['class'] = predictions
    submission.to_csv('./submission.csv', index=False)
    return submission

# %%
submission = build_submission(predicted_test)
submission
# Out:
#       class
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ...     ...
# 2087  false
# 2088  false
# 2089  false
# 2090  false
# 2091  false
#
# [2092 rows x 1 columns]

# %%
submission.to_csv('./submission.csv')

# %%
f1_score(df_val['label'], predicted_val)
# Out:
# /home/rubelrennfix/.virtualenvs/hckt04/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1254: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if pos_label not in present_labels:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-1fb4c38437bd> in <module>
# ----> 1 f1_score(df_val['label'], predicted_val)
#
# ~/.virtualenvs/hckt04/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.virtualenvs/hckt04/lib/python3.6/site-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1045                        pos_label=pos_label, average=average,
#    1046                        sample_weight=sample_weight,
# -> 1047                        zero_division=zero_division)
#    1048
#    1049
#
# ~/.virtualenvs/hckt04/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.virtualenvs/hckt04/lib/python3.6/site-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1173                                                  warn_for=('f-score',),
#    1174                                                  sample_weight=sample_weight,
# -> 1175                                                  zero_division=zero_division)
#    1176     return f
#    1177
#
# ~/.virtualenvs/hckt04/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.virtualenvs/hckt04/lib/python3.6/site-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1432         raise ValueError("beta should be >=0 in the F-beta score")
#    1433     labels = _check_set_wise_labels(y_true, y_pred, average, labels,
# -> 1434                                     pos_label)
#    1435
#    1436     # Calculate tp_sum, pred_sum, true_sum ###
#
# ~/.virtualenvs/hckt04/lib/python3.6/site-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1255                 if len(present_labels) >= 2:
#    1256                     raise ValueError("pos_label=%r is not a valid label: "
# -> 1257                                      "%r" % (pos_label, present_labels))
#    1258             labels = [pos_label]
#    1259         else:
#
# ValueError: pos_label=1 is not a valid label: array(['false', 'true'], dtype='<U5')

# %%
f1_score(y_true=df_val["label"].values, y_pred=predicted_val, pos_label="true")
# Out:
# 0.0

# %%
build_submission(predicted_test).value_counts()
# Out:
# class
# false    2090
# true        2
# dtype: int64

# %%
sample_submission
# Out:
#     class
# 0   False
# 1    True
# 2    True
# 3    True
# 4   False
# 5   False
# 6   False
# 7    True
# 8    True
# 9    True
# 10   True
# 11  False
# 12   True
# 13   True
# 14  False
# 15  False
# 16   True
# 17  False
# 18  False
# 19   True
# 20  False
# 21  False
# 22   True
# 23   True
# 24  False
# 25   True
# 26   True
# 27   True
# 28  False
# 29  False
# 30  False
# 31  False
# 32  False
# 33  False
# 34   True
# 35  False
# 36  False
# 37  False
# 38  False
# 39  False
# 40  False
# 41   True
# 42   True
# 43   True
# 44   True
# 45   True
# 46   True
# 47   True
# 48  False
