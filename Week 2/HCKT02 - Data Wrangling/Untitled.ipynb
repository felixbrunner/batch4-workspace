# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
df_test = pd.read_csv('data/test.csv')
df_train = pd.read_csv('data/train.csv')

# %%
id_list = list(df_test.game_id.append(df_train.game_id))

# %%
id_list
# Out:
# ['9564c32b-dad9-4292-8efb-8fa41f026fe9',
#  '8160b53f-417a-416c-bd66-41b115e91039',
#  '5bd6d56b-e337-4f61-83b6-cfe21a481892',
#  '614fd189-86c9-4f44-9b13-cf980e1ccc9f',
#  '539f6975-88f2-40ea-8d22-4b500370e971',
#  'a49eedc5-7128-45ab-b466-6ee57cc23ce7',
#  'c8429c3c-5d22-4d60-8591-6010bd38f064',
#  'aebac5cf-3fa6-4db5-8321-0b0585175d9e',
#  '45c10445-f024-453e-a716-17f62e3186aa',
#  '62aad2c3-d23b-40f1-bcda-7a4105549bb0',
#  '81bb480b-da84-443e-b262-1703335aeebf',
#  '9d836310-3aa2-4f79-8a47-d0427aca9e98',
#  '67893ca0-b45c-42cd-940f-6323188fbd73',
#  'e9d1d3b8-4ba5-4887-ba2e-fcd5d1962cf7',
#  '1f54100d-1dc1-455e-a72d-8c22330ceae5',
#  '80d7a315-7b2e-44d1-9d75-1000375821a9',
#  'd855f1cd-7470-4dba-b17e-fdb015307b3f',
#  '9f423985-d251-4242-9cc7-80d7e7ec8408',
#  '81a132dc-8412-4be2-b798-1abc10d96046',
#  'f4622f71-606c-4630-b39a-c0e353f9c58f',
#  'd265047e-c5ed-4e3e-882a-7923aa9a0ac4',
#  'ad5051d3-0b0d-4ed7-a442-5390afe7b40c',
#  '66728656-8bfc-4fcf-a5ee-35b3326b5070',
# ...

# %%
df_train.head()
# Out:
#    Year  Season blueTeamTag  bResult redTeamTag  gamelength  \
# 0  2016  Summer          TT        1        HWA          50
# 1  2016  Summer         CRW        0        HWA          31
# 2  2016  Summer         SUP        1        AUR          50
# 3  2016  Spring         JAG        1        SSB          40
# 4  2016  Spring         SIN        0        CHF          36
#
#                                 game_id
# 0  b96f782c-da04-4641-9306-68968036bfd9
# 1  2a7e2cb1-5ac2-4ea2-bd18-0b261e43345a
# 2  e04ed84d-929b-4f0e-a769-e7bffc2b5162
# 3  8829614a-313e-413c-9520-d95d7b95af31
# 4  db2cf98d-a55e-4e28-9702-d7363fad2ebb

# %%
df_train.gamelength.hist()
# Out:
# <AxesSubplot:>
